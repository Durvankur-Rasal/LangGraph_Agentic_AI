# %%
from langgraph.graph import StateGraph, START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGoogleGenerativeAI(model="gemini-2.5-pro")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    #fetch title
    title = state["title"]
    
    #call the llm to generate outline
    prompt = f"Write an outline for a blog post about {title}"
    outline = model.invoke(prompt).content
    
    #update state 
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    #fetch title and outline
    title = state['title']
    outline = state['outline']
    
    prompt = f'write a detailed blog on the title - {title} and outline - {outline}'
    content = model.invoke(prompt).content
    
    #update state 
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

# %%
print(final_state["outline"])
# Out:
# Of course! Here is a comprehensive outline for a blog post about the rise of Artificial Intelligence in India. This structure is designed to be engaging, informative, and easy for a writer to flesh out.
#
# ---
#
# ### **Blog Post Outline: The Rise of AI in India**
#
# **Possible Blog Post Titles:**
#
# *   The AI Elephant Awakens: How India is Shaping the Future of Artificial Intelligence
# *   From Jugaad to Jarvis: Charting India's Unstoppable AI Ascent
# *   India's AI Revolution: More Than Just Code, It's a National Mission
# *   Decoding Bharat's AI: The Drivers, Challenges, and a Glimpse into the Future
#
# ---
#
# #### **1. Introduction: The Tipping Point**
#
# *   **Hook:** Start with a powerful statistic or a relatable, real-world example.
#     *   *Example:* "From the UPI payment that just processed in seconds to a farmer in rural Maharashtra getting a crop disease prediction on their phone, Artificial Intelligence is no longer a futuristic concept in India—it's a present-day reality."
# *   **Thesis Statement:** State the core argument of the post.
#     *   *Example:* "India is not just participating in the global AI race; it is leveraging its unique demographic, data, and digital infrastructure to emerge as a formidable AI powerhouse with the potential to build solutions for a billion people."
# *   **Roadmap:** Briefly tell the reader what the post will cover (the key drivers, real-world applications, challenges, and what the future holds).
#
# ---
#
# #### **2. The "Why India, Why Now?" - The Perfect Storm for AI Growth**
#
# *   **A. The Data Deluge: Fuel for the AI Engine**
#     *   Explain how India became one of the world's largest data-generating nations.
#     *   Mention key factors: The "Jio Effect" (cheap mobile data), massive smartphone penetration, and the digital payments revolution (UPI).
#     *   Emphasize: Data is the raw material for training AI models, and India has it in abundance.
#
# *   **B. The Talent Pool: A Demographic Dividend**
#     *   Highlight India's massive population of STEM graduates and engineers.
#     *   Mention the role of premier institutions like IITs, IISc, and IIITs in producing top-tier AI/ML talent.
#     *   Acknowledge the growing ecosystem of online courses and upskilling platforms.
#
# *   **C. Government as a Catalyst: The Top-Down Push**
#     *   Briefly introduce key government initiatives like "Digital India" and the "National Strategy for Artificial Intelligence (NITI Aayog)."
#     *   Mention the newly announced **IndiaAI Mission** and its focus on building domestic compute infrastructure and AI ecosystems.
#
# *   **D. A Thriving Startup Ecosystem**
#     *   Note that India has the third-largest startup ecosystem in the world.
#     *   Explain how many of these startups are "AI-first," building innovative solutions for both Indian and global problems.
#
# ---
#
# #### **3. AI in Action: Transforming Key Indian Sectors**
#
# *(This section should be filled with specific, compelling examples.)*
#
# *   **A. Healthcare:**
#     *   AI-powered diagnostics (e.g., detecting diabetic retinopathy from retinal scans).
#     *   Predictive healthcare and personalized medicine.
#     *   Efficient hospital management systems.
#
# *   **B. Finance (Fintech & BFSI):**
#     *   Fraud detection in real-time for digital transactions.
#     *   AI-based credit scoring for the unbanked and underbanked population.
#     *   Conversational AI (chatbots) for customer service in banks.
#
# *   **C. Agriculture (Agritech):**
#     *   Precision farming: Using AI with satellite/drone imagery for crop health monitoring.
#     *   Pest prediction models to help farmers protect their yields.
#     *   Optimizing supply chains to reduce waste.
#
# *   **D. E-commerce & Retail:**
#     *   Hyper-personalization of recommendations for shoppers.
#     *   AI-driven logistics and warehouse management (e.g., GreyOrange).
#     *   Conversational commerce via platforms like WhatsApp.
#
# *   **E. Governance and Public Services:**
#     *   Using AI for traffic management in smart cities.
#     *   Language translation tools to bridge India's linguistic diversity (e.g., Project Bhashini).
#     *   Optimizing public distribution systems.
#
# ---
#
# #### **4. The Architects: Key Players in India's AI Story**
#
# *   **A. Homegrown Startups:**
#     *   Name-drop a few innovative startups to make it concrete (e.g., Haptik, Locus, Krutrim AI).
# *   **B. IT Services Giants:**
#     *   Mention how companies like TCS, Infosys, and Wipro are building large-scale AI capabilities and serving global clients from India.
# *   **C. Global Tech's India Hub:**
#     *   Highlight the massive R&D centers of Google, Microsoft, Amazon, etc., in India, which are doing cutting-edge AI research.
# *   **D. Academia and Research:**
#     *   Reiterate the role of top universities in foundational research and collaboration with the industry.
#
# ---
#
# #### **5. Navigating the Hurdles: Challenges on the Road Ahead**
#
# *   **A. The Skill Gap:**
#     *   The difference between having many engineers and having enough *highly-skilled AI specialists*.
# *   **B. Infrastructure and Compute Power:**
#     *   The need for more high-performance computing (HPC) infrastructure to train large models. The IndiaAI Mission aims to address this.
# *   **C. Data Privacy and Security:**
#     *   Discuss the importance of robust data protection laws (like the Digital Personal Data Protection Act) and the ethical use of data.
# *   **D. Algorithmic Bias and Inclusivity:**
#     *   The risk of AI models being biased against India's diverse languages, dialects, and demographics. The need for "responsible AI."
#
# ---
#
# #### **6. The Future is Intelligent: What's Next for AI in India?**
#
# *   **A. The Generative AI Wave and "Bharat's LLMs":**
#     *   Discuss the emergence of India-specific Large Language Models (LLMs) trained on Indian languages and cultural contexts.
# *   **B. AI for Social Good ("Bharat AI"):**
#     *   The vision of using AI to solve India's unique, large-scale problems in education, healthcare, and agriculture.
# *   **C. From an "AI Service Nation" to an "AI Product Nation":**
#     *   The shift from providing AI services to creating globally competitive AI products and platforms.
# *   **D. The Evolving Regulatory Landscape:**
#     *   Briefly touch on the need for agile regulations that foster innovation while mitigating risks.
#
# ---
#
# #### **7. Conclusion: India's Moment in the AI Sun**
#
# *   **Summarize Key Takeaways:** Briefly recap the main points—India's unique advantages (data, talent), its rapid adoption across sectors, and the challenges it must overcome.
# *   **Final Thought-Provoking Statement:** End with a powerful and optimistic vision for the future.
#     *   *Example:* "India's AI journey is not about mimicking the West; it's about pioneering a new, inclusive model of technological development. By building for its own billion-plus population, India may well create the AI blueprint for the rest of the developing world."
# *   **Call to Action (CTA):**
#     *   *Example:* "What do you think is the most exciting application of AI in India? Share your thoughts in the comments below!"

# %%
print(final_state['content'])
# Out:
# Of course! Here is a detailed blog post written based on the comprehensive outline provided.
#
# ---
#
# ### **From Jugaad to Jarvis: Charting India's Unstoppable AI Ascent**
#
# From the UPI payment that just processed in seconds on your phone to a farmer in rural Maharashtra getting a crop disease prediction on their app, Artificial Intelligence is no longer a futuristic concept in India—it's a present-day reality, woven into the very fabric of its digital life. The world is watching as the nation of a billion dreams rapidly transforms into a hub of AI innovation.
#
# India is not just participating in the global AI race; it is leveraging its unique demographic, data, and digital infrastructure to emerge as a formidable AI powerhouse. This journey is about more than just code; it's a national mission with the potential to build solutions not just for India, but for the world.
#
# In this post, we'll decode Bharat's AI revolution by exploring the key drivers fueling its growth, seeing AI in action across critical sectors, understanding the challenges ahead, and glimpsing into an intelligent future.
#
# ### **The "Why India, Why Now?" - The Perfect Storm for AI Growth**
#
# Several powerful forces have converged to create the ideal conditions for an AI explosion in India.
#
# #### **A. The Data Deluge: Fuel for the AI Engine**
#
# Artificial Intelligence models are voracious learners, and their primary food is data. In the last decade, India has transformed into one of the world's largest data-generating nations. The catalyst was the **"Jio Effect,"** which crashed mobile data prices and brought hundreds of millions of Indians online. Coupled with massive smartphone penetration and the world's most successful digital payments system (UPI), India now generates a colossal amount of diverse data every second. This data—from transactions, social media, and consumption patterns—is the rich, raw material needed to train sophisticated and relevant AI models.
#
# #### **B. The Talent Pool: A Demographic Dividend**
#
# India is home to the world's largest youth population and produces millions of STEM (Science, Technology, Engineering, and Mathematics) graduates annually. Premier institutions like the IITs, IISc, and IIITs have long been crucibles for top-tier tech talent. Now, this immense human resource is pivoting towards AI and Machine Learning, supported by a booming ecosystem of online courses and upskilling platforms that are making AI education accessible to all.
#
# #### **C. Government as a Catalyst: The Top-Down Push**
#
# The Indian government has recognized AI's strategic importance and is actively fostering its growth. Foundational initiatives like **"Digital India"** built the digital highways, while the **"National Strategy for Artificial Intelligence"** by NITI Aayog laid out a clear roadmap. More recently, the government announced the ambitious **IndiaAI Mission**, a ~$1.2 billion-dollar plan focused on building domestic compute infrastructure (supercomputers and GPUs), creating datasets, and nurturing a vibrant AI ecosystem. This top-down push provides the policy stability and resources needed for long-term growth.
#
# #### **D. A Thriving Startup Ecosystem**
#
# With the third-largest startup ecosystem in the world, India is a hotbed of innovation. A new wave of entrepreneurs is building "AI-first" companies, creating groundbreaking solutions for both uniquely Indian challenges and global markets. These nimble startups are at the forefront of applying AI in novel ways, driving competition and accelerating adoption.
#
# ### **AI in Action: Transforming Key Indian Sectors**
#
# The true measure of AI's rise is its real-world impact. Here’s how it’s reshaping critical industries:
#
# *   **Healthcare:** AI is becoming a doctor's best assistant. AI-powered diagnostic tools are helping detect conditions like diabetic retinopathy from retinal scans with incredible accuracy in remote areas. Predictive models are helping hospitals manage patient loads, and personalized medicine is becoming a closer reality.
# *   **Finance (Fintech & BFSI):** In a country that processes billions of digital transactions, AI is the silent guardian. It powers real-time fraud detection systems, safeguarding the financial ecosystem. Fintech companies are using AI-based credit scoring models to provide loans to the unbanked and underbanked, fostering financial inclusion. AI-powered chatbots are now the first line of customer service for most major banks.
# *   **Agriculture (Agritech):** For a nation where over half the population depends on agriculture, AI is a game-changer. Agritech startups are using satellite and drone imagery with AI for **precision farming**—monitoring crop health, soil moisture, and nutrient levels. Pest prediction models are helping farmers take preventive action, protecting their yields and income.
# *   **E-commerce & Retail:** AI is the engine behind the hyper-personalized shopping experience on platforms like Flipkart and Amazon. It recommends products, optimizes supply chains for faster delivery with companies like **GreyOrange**, and powers conversational commerce on platforms like WhatsApp, allowing you to order groceries by simply chatting with a bot.
# *   **Governance and Public Services:** The government is leveraging AI to improve citizen services. It's being used for intelligent traffic management in smart cities and to power language translation tools like **Project Bhashini**, which aims to break down linguistic barriers across India's diverse states.
#
# ### **The Architects: Key Players in India's AI Story**
#
# This revolution is being led by a diverse cast of players:
#
# *   **Homegrown Startups:** Innovative companies like **Haptik** (conversational AI), **Locus** (logistics optimization), and the newly launched **Krutrim AI** (building India's own Large Language Models) are making global waves.
# *   **IT Services Giants:** Titans like **TCS, Infosys, and Wipro** have pivoted aggressively, building massive AI and data science teams to offer sophisticated AI solutions to their global clientele from their Indian delivery centers.
# *   **Global Tech's India Hub:** The world's biggest tech companies—Google, Microsoft, Amazon, and others—have established massive R&D centers in India. These centers are not just back-offices; they are conducting cutting-edge AI research and development for global products.
# *   **Academia and Research:** Top universities continue to be the bedrock of foundational research, collaborating closely with the industry to push the boundaries of AI.
#
# ### **Navigating the Hurdles: Challenges on the Road Ahead**
#
# The path to becoming an AI leader is not without its obstacles:
#
# *   **The Skill Gap:** While India has many engineers, there is a shortage of *highly-skilled AI specialists*, researchers, and PhDs who can build next-generation models.
# *   **Infrastructure and Compute Power:** Training large, complex AI models requires immense computational power (GPUs). While the IndiaAI Mission aims to address this, access to high-performance computing remains a bottleneck.
# *   **Data Privacy and Security:** In a data-rich country, ensuring the ethical and secure use of data is paramount. Robust implementation of laws like the **Digital Personal Data Protection Act** is crucial to building trust.
# *   **Algorithmic Bias and Inclusivity:** If AI models are trained on biased data, they will produce biased outcomes. Ensuring AI is fair and inclusive for India's vast diversity of languages, dialects, and demographics is a critical challenge that requires a focus on "Responsible AI."
#
# ### **The Future is Intelligent: What's Next for AI in India?**
#
# The next phase of India's AI journey looks even more exciting:
#
# *   **The Generative AI Wave and "Bharat's LLMs":** The focus is shifting to building India-specific Large Language Models (LLMs) trained on Indian languages and cultural contexts, promising more relevant and accessible AI for all citizens.
# *   **AI for Social Good ("Bharat AI"):** The ultimate vision is to use AI to solve India's most pressing, large-scale problems in education, public health, and judicial efficiency—building an AI for a billion people.
# *   **From an "AI Service Nation" to an "AI Product Nation":** The ambition is to transition from providing AI services to creating globally competitive AI products and platforms, moving up the value chain and capturing a larger share of the global AI market.
#
# ### **Conclusion: India's Moment in the AI Sun**
#
# India stands at a historic inflection point. The confluence of massive data, a vast talent pool, proactive government support, and a vibrant startup culture has created a unique advantage. While challenges remain, the momentum is undeniable.
#
# India's AI journey is not about mimicking the West; it's about pioneering a new, inclusive model of technological development. By building for its own billion-plus population, India may well create the AI blueprint for the rest of the developing world. The AI elephant has truly awakened, and its footsteps will shape the future.
#
# ---
#
# ***What do you think is the most exciting application of AI in India? Share your thoughts in the comments below!***
